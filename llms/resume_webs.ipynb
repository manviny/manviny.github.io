# %% [markdown]
# ### Ejercicio, resumen webs
#
# Ollama debe estar corriendo en local:
# [http://localhost:11434/](http://localhost:11434/)

# %%
# importaciones

import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display

# %%
# Constantes

OLLAMA_API = "http://localhost:11434/api/chat"
HEADERS = {"Content-Type": "application/json"}
MODEL = "llama3.2"

# %%
# Crea un mensaje

messages = [
    {"role": "user", "content": "Describe some of the business applications of Generative AI"}
]

# %%
payload = {
        "model": MODEL,
        "messages": messages,
        "stream": False
    }

# %%
# Comprobamos que el modelo esta cargadfo

# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
response = requests.post(OLLAMA_API, json=payload, headers=HEADERS)
print(response.json()['message']['content'])
# Out:
# Generative AI has numerous business applications across various industries. Some examples include:
#
# 1. **Content Creation**: Generative AI can be used to generate high-quality content such as blog posts, social media posts, and product descriptions. This can save time and resources for businesses that need to produce a large volume of content.
# 2. **Image and Video Generation**: Generative AI can create realistic images and videos, which can be used in applications such as advertising, entertainment, and education. For example, companies can use generative AI to generate product images or animations for their marketing campaigns.
# 3. **Chatbots and Virtual Assistants**: Generative AI can be used to develop more advanced chatbots and virtual assistants that can understand natural language and respond accordingly.
# 4. **Predictive Analytics**: Generative AI can be used to predict future trends, customer behavior, and market conditions. This can help businesses make informed decisions about their products and services.
# 5. **Recommendation Systems**: Generative AI can be used to develop more accurate recommendation systems that suggest products or services based on a user's past behavior and preferences.
# 6. **Product Design**: Generative AI can be used to generate designs for new products, such as furniture, clothing, or electronics. This can help businesses speed up the design process and reduce costs.
# 7. **Marketing Automation**: Generative AI can be used to automate marketing tasks such as email marketing, lead generation, and social media management.
# 8. **Financial Analysis**: Generative AI can be used to analyze large datasets of financial information to identify trends and predict future market movements.
# 9. **Customer Service**: Generative AI can be used to develop more advanced customer service systems that can understand natural language and respond accordingly.
# 10. **Supply Chain Optimization**: Generative AI can be used to optimize supply chain operations by predicting demand, identifying bottlenecks, and optimizing inventory levels.
#
# Some specific business applications of generative AI include:
#
# * **eBay's Product Description Generator**: eBay uses generative AI to generate product descriptions for its sellers, saving time and resources.
# * **Netflix's Content Recommendation System**: Netflix uses generative AI to develop a recommendation system that suggests TV shows and movies based on user behavior and preferences.
# * **IKEA's Product Design Tool**: IKEA uses generative AI to design new products and furniture designs, reducing the need for physical prototypes.
# * **Amazon's Virtual Assistant**: Amazon uses generative AI to develop a virtual assistant that can understand natural language and respond accordingly.
#
# These are just a few examples of how Generative AI is being used in business applications. The possibilities are vast and continue to expand as the technology improves.

# %% [markdown]
# #### Ahora con el paqquete de ollama

# %%
import ollama

response = ollama.chat(model=MODEL, messages=messages)
print(response['message']['content'])
# Out:
# Generative AI has numerous business applications across various industries. Here are some examples:
#
# 1. **Content Generation**: Generative AI can generate high-quality content such as articles, social media posts, product descriptions, and more. This can help businesses save time and resources on content creation.
# 2. **Marketing Automation**: Generative AI can be used to create personalized marketing messages, emails, and ads based on customer data and preferences.
# 3. **Product Design and Development**: Generative AI can assist in the design of products such as furniture, fashion items, and electronics by generating 3D models, prototypes, and even entire product lines.
# 4. **Image and Video Generation**: Generative AI can generate high-quality images and videos for various applications such as advertising, e-learning, and entertainment.
# 5. **Chatbots and Virtual Assistants**: Generative AI can power chatbots and virtual assistants to provide personalized customer support and improve user experience.
# 6. **Predictive Analytics**: Generative AI can analyze large datasets to predict customer behavior, forecast sales, and identify potential risks.
# 7. **Music and Audio Generation**: Generative AI can create music, sound effects, and audio tracks for various applications such as film, television, and video games.
# 8. **Automated Writing Assistance**: Generative AI can assist writers in generating ideas, outlines, and even entire drafts of articles, books, and other written content.
# 9. **Data Augmentation**: Generative AI can generate new data points to augment existing datasets, which can help improve the accuracy of machine learning models.
# 10. **Creative Industries**: Generative AI can be used in various creative industries such as art, fashion, and architecture to generate new ideas, designs, and concepts.
#
# Some specific business use cases include:
#
# * A fashion brand using generative AI to design new clothing lines and product collections
# * A marketing agency using generative AI to create personalized ads and social media content for clients
# * A technology company using generative AI to power chatbots and virtual assistants for customer support
# * A music streaming service using generative AI to create original music tracks and playlists
#
# These are just a few examples of the many business applications of Generative AI. As the technology continues to evolve, we can expect to see even more innovative use cases across various industries.
