# %% [markdown]
# ### Ejercicio, resumen webs
#
# Ollama debe estar corriendo en local:
# [http://localhost:11434/](http://localhost:11434/)

# %%
# importaciones

import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display

# %%
# Constantes

OLLAMA_API = "http://localhost:11434/api/chat"
HEADERS = {"Content-Type": "application/json"}
MODEL = "llama3.2"

# %%
# Crea un mensaje

messages = [
    {"role": "user", "content": "Describe some of the business applications of Generative AI"}
]

# %%
payload = {
        "model": MODEL,
        "messages": messages,
        "stream": False
    }

# %%
# Comprobamos que el modelo esta cargadfo

# !ollama pull llama3.2
# Out:
# pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠹ pulling manifest ⠼ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠏ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
response = requests.post(OLLAMA_API, json=payload, headers=HEADERS)
print(response.json()['message']['content'])
# Out:
# Generative AI has numerous business applications across various industries. Some examples include:
#
# 1. **Content Generation**: Generative AI can be used to generate high-quality content such as blog posts, social media posts, product descriptions, and more. This can help businesses save time and resources while maintaining consistency in their content.
# 2. **Image and Video Creation**: Generative AI can create realistic images and videos that can be used for various applications such as marketing, advertising, and entertainment.
# 3. **Chatbots and Virtual Assistants**: Generative AI can be used to power chatbots and virtual assistants, enabling businesses to provide more personalized and efficient customer service.
# 4. **Product Design**: Generative AI can aid in product design by generating 2D and 3D models, prototypes, and even entire product lines.
# 5. **Recommendation Systems**: Generative AI can be used to create personalized recommendation systems that suggest products or services based on user behavior and preferences.
# 6. **Data Augmentation**: Generative AI can be used to generate new data samples that can be used to augment existing datasets, making them more diverse and representative.
# 7. **Marketing Automation**: Generative AI can be used to automate marketing tasks such as email marketing, social media advertising, and lead generation.
# 8. **Customer Service Automation**: Generative AI can be used to automate customer service tasks such as answering frequently asked questions, responding to common complaints, and even resolving simple issues on its own.
# 9. **Creative Writing and Storytelling**: Generative AI can be used to generate creative writing content such as short stories, poetry, and even entire scripts for films or TV shows.
# 10. **Predictive Maintenance**: Generative AI can be used to predict equipment failures and maintenance needs, enabling businesses to schedule repairs and reduce downtime.
# 11. **Risk Analysis and Modeling**: Generative AI can be used to analyze large datasets and identify patterns that may indicate potential risks or opportunities.
# 12. **Human Resource Management**: Generative AI can be used to automate tasks such as candidate sourcing, resume screening, and even interview scheduling.
# 13. **Supply Chain Optimization**: Generative AI can be used to optimize supply chain operations by predicting demand, identifying bottlenecks, and optimizing inventory levels.
# 14. **Financial Analysis and Modeling**: Generative AI can be used to analyze large datasets and identify trends that may indicate potential investment opportunities or risks.
# 15. **Cybersecurity Threat Detection**: Generative AI can be used to detect and respond to cybersecurity threats by analyzing network traffic and identifying patterns that may indicate a threat.
#
# These are just a few examples of the many business applications of Generative AI. As the technology continues to evolve, we can expect to see even more innovative applications across various industries.

# %% [markdown]
# #### Ahora con el paqquete de ollama

# %%
import ollama

response = ollama.chat(model=MODEL, messages=messages)
print(response['message']['content'])
# Out:
# Generative AI has numerous business applications across various industries, including:
#
# 1. **Content Creation**: AI-powered tools can generate high-quality content such as articles, social media posts, product descriptions, and more. This can save time and resources for businesses, while also improving content consistency and quality.
# 2. **Product Design**: Generative AI can be used to design new products, such as furniture, electronics, or fashion items. It can create 3D models, prototypes, and even physical products with high accuracy.
# 3. **Marketing Automation**: AI-powered tools can generate personalized marketing campaigns, product recommendations, and customer service responses. This can help businesses automate routine tasks, improve customer engagement, and increase sales.
# 4. **Data Analysis and Visualization**: Generative AI can analyze large datasets and create visualizations that help businesses understand complex patterns and trends. This can inform strategic decisions and drive business growth.
# 5. **Supply Chain Optimization**: AI-powered tools can optimize supply chain operations by predicting demand, identifying bottlenecks, and recommending efficient logistics routes.
# 6. **Cybersecurity**: Generative AI can be used to detect and respond to cyber threats in real-time. It can analyze network traffic, identify patterns, and recommend security measures to protect against attacks.
# 7. **Customer Service**: AI-powered chatbots can generate responses to customer inquiries, helping businesses provide 24/7 support and improve customer satisfaction.
# 8. **Creative Agencies**: Generative AI can be used by creative agencies to generate ideas for marketing campaigns, product designs, or social media content.
# 9. **Education**: AI-powered tools can create personalized learning experiences, generating customized educational materials, assessments, and feedback.
# 10. **Financial Services**: Generative AI can be used in financial services to generate investment recommendations, analyze market trends, and identify potential risks.
#
# Some specific examples of business applications include:
#
# * **Amazon's product suggestions**: Amazon uses generative AI to suggest products to customers based on their browsing and purchase history.
# * **Netflix's content recommendations**: Netflix uses generative AI to recommend TV shows and movies to users based on their viewing habits.
# * **Google's AdWords**: Google uses generative AI to optimize ad targeting, pricing, and bidding strategies for advertisers.
# * **IBM's Watson**: IBM's Watson platform uses generative AI to analyze large datasets and provide insights for businesses across various industries.
#
# These are just a few examples of the many business applications of Generative AI. As the technology continues to evolve, we can expect to see even more innovative use cases in various industries.
