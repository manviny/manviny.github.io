# %% [markdown]
# ### RAG
# - Retrieval-Augmented Generation

# %% [markdown]
# ##### EJERCICIO
# - Crear RAG con los documentos adjuntos, se debe cambiar el codigo para usar otro modelo
# - Los documentos estan en ingles, deberias aplicar un modelo OpenSource en ingles
# - Buscar varios modelos en HugginFace que entiendan español, buscar documentos en español y probarlo
